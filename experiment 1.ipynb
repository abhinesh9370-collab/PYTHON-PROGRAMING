# %% [markdown]
# ## 1 Python Installation and Starting with Python

# %% [markdown]
# 1 Python Installation
#
# 2 Go to python.org
#
# 3 Download Python 3.x
#
# 4 Install it (✔ check Add Python to PATH)
#
# 5 After installation, open IDLE (Python GUI)

# %% [markdown]
# ## 2 Write Python programs to print strings in the given manner:

# %% [markdown]
# # a) Hello Everyone !!!

# %%
print("Hello Everyone !!!")
# Out:
# Hello Everyone !!!

# %% [markdown]
# # b)Hello

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %% [markdown]
# # c) Hello
#              World

# %%
print("Hello")
print("      World")
# Out:
# Hello
#       World

# %% [markdown]
# # d) 'Rohit’s date of birth is 12\05\1999'

# %%
print("Rohit's date of birth is 12\\05\\1999")
# Out:
# Rohit's date of birth is 12\05\1999

# %% [markdown]
# ## 3. Declare String Variable x

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# ## 4. Different Data Types and Printing Values## 4.

# %%
a = 10          
b = 5.5         
c = "Python"    
d = True        

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 5.5
# Python
# True

# %% [markdown]
# ## 5. First Name + Last Name

# %%
a = "Abhinesh"
b = "Kumar"

print(a + " " + b)
# Out:
# Abhinesh Kumar

# %% [markdown]
# ## 6. First Name, Nickname, Last Name

# %%
first_name = "abhinesh"
nickname = "kumar"
last_name = "singh"

print(first_name + " (" + nickname + ") " + last_name)
# Out:
# abhinesh (kumar) singh

# %% [markdown]
# ## 7.

# %%
name = "ABHINESH KUMAR"
sap_id = "590029100"
dob = "13 Oct 1999"
address1 = "UPES"
address2 = "Bidholi Campus"
pincode = "248007"
programme = "AI & ML"
semester = "2"

print("NAME:", name)
print("SAP ID:", sap_id)
print("DATE OF BIRTH:", dob)
print("ADDRESS:", address1)
print("        ", address2)
print("        Pincode:", pincode)
print("Programme:", programme)
print("Semester:", semester)
# Out:
# Abhinesh
# 20
# Bca
